# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5240, 3082, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'term', 'anarchism', 'originated', 'term', 'of', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.408327
# Nearest to than: tensors, plutocracy, cabral, unit, encryption, lusp, telco, firsts,
# Nearest to s: guts, testimonies, kievan, spoons, strand, ravine, mock, corinthian,
# Nearest to nine: gelatinous, schmidt, transform, lynda, elsa, bisexuals, chuck, sava,
# Nearest to its: masovia, gemstone, somatic, sephiroth, ambedkar, particularity, silvio, costing,
# Nearest to united: veiled, long, ebenezer, gia, klamath, bethune, reducing, falsetto,
# Nearest to with: donor, membered, pxe, anatolian, benefactor, diaspora, bootstrapping, lar,
# Nearest to who: reveals, yellow, heraldic, deafness, jirga, enslavement, nonempty, delighted,
# Nearest to which: hardin, respite, alai, jeux, cannot, salutation, blob, hemorrhagic,
# Nearest to on: theogony, tanoana, toned, uucp, modernists, highgate, nfl, pigot,
# Nearest to it: cedes, stg, hellene, echelon, pouch, phenomenological, blanton, main,
# Nearest to would: amended, dci, improper, navigating, ambient, upstart, conceptually, evaluations,
# Nearest to were: blend, clos, orientation, cyber, chung, ugle, overlay, yhwh,
# Nearest to when: woodrow, algonquin, suck, macrobiotics, garnier, upward, offenses, addons,
# Nearest to are: y, radioactive, polos, vancouver, blair, danios, washing, waterfalls,
# Nearest to of: generously, acquire, venerated, munitions, screaming, ascend, lapd, haudenosaunee,
# Nearest to there: heckman, ladders, elbing, ipo, rocky, fractional, shovel, micrograms,
# Average loss at step 2000: 4.364226
# Average loss at step 4000: 3.867164
# Average loss at step 6000: 3.790648
# Average loss at step 8000: 3.686528
# Average loss at step 10000: 3.620457
# Nearest to than: cabral, encryption, plutocracy, tensors, hemorrhage, vicarage, telco, mooring,
# Nearest to s: his, and, carriage, was, discrepancies, ashamed, prozac, hilbert,
# Nearest to nine: eight, six, seven, five, zero, four, three, two,
# Nearest to its: the, masovia, their, fencers, jarre, harbors, his, somatic,
# Nearest to united: bethune, reducing, oedipus, ebenezer, suspects, beatrice, veiled, klamath,
# Nearest to with: for, as, website, by, in, into, gymnast, excitement,
# Nearest to who: and, he, cutlery, theodora, they, then, not, alu,
# Nearest to which: this, that, also, it, often, there, and, penguin,
# Nearest to on: in, theogony, by, of, segregated, toned, noc, from,
# Nearest to it: he, there, this, not, which, that, they, perfective,
# Nearest to would: accords, will, improper, can, could, dci, discourses, worthington,
# Nearest to were: are, was, cyber, reintroducing, scope, orientation, had, have,
# Nearest to when: upward, fayyum, veritas, macrobiotics, wolfe, patmos, erotica, gurdjieff,
# Nearest to are: were, is, have, be, was, consort, sutherland, fi,
# Nearest to of: in, for, carbonates, absinthe, following, ascend, on, bono,
# Nearest to there: it, they, compounding, not, heckman, percentile, he, growing,
# Average loss at step 12000: 3.602703
# Average loss at step 14000: 3.574068
# Average loss at step 16000: 3.410274
# Average loss at step 18000: 3.460052
# Average loss at step 20000: 3.540486
# Nearest to than: or, cabral, encryption, telco, plutocracy, obstetrics, humayun, vicarage,
# Nearest to s: vinland, cripple, carriage, yourselves, picket, his, inflections, pastures,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to its: their, his, the, power, harbors, wozniak, refuge, expose,
# Nearest to united: reducing, bethune, oedipus, laserdisc, upstairs, beatrice, mutual, ebenezer,
# Nearest to with: in, for, by, between, or, at, into, beaulieu,
# Nearest to who: he, which, they, she, then, theodora, arameans, also,
# Nearest to which: this, who, also, that, it, there, often, when,
# Nearest to on: in, at, against, theogony, tigray, uucp, segregated, guangdong,
# Nearest to it: he, there, this, they, which, she, not, what,
# Nearest to would: will, can, could, may, might, must, should, accords,
# Nearest to were: are, was, had, have, be, is, aki, been,
# Nearest to when: zemin, where, which, that, during, while, wroc, veritas,
# Nearest to are: were, is, have, was, be, consort, transfusions, sutherland,
# Nearest to of: absinthe, nndb, carbonates, for, confiscated, in, partial, ascend,
# Nearest to there: it, they, he, which, still, not, often, also,
# Average loss at step 22000: 3.499749
# Average loss at step 24000: 3.489684
# Average loss at step 26000: 3.481317
# Average loss at step 28000: 3.483652
# Average loss at step 30000: 3.503930
# Nearest to than: encryption, cabral, or, telco, obstetrics, piper, particular, nephites,
# Nearest to s: his, vinland, cruz, isbn, online, fl, neanderthals, nasional,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to its: their, the, his, power, evacuated, her, translating, somatic,
# Nearest to united: reducing, bethune, laserdisc, oedipus, upstairs, confederate, render, suspects,
# Nearest to with: between, for, by, in, under, when, among, from,
# Nearest to who: he, they, she, which, and, there, arameans, inverting,
# Nearest to which: this, that, also, what, who, it, there, these,
# Nearest to on: in, during, upon, from, under, at, for, guangdong,
# Nearest to it: he, there, this, she, they, inverting, which, also,
# Nearest to would: will, can, could, may, must, should, might, to,
# Nearest to were: are, was, have, had, is, been, aki, those,
# Nearest to when: where, if, after, during, before, zemin, while, though,
# Nearest to are: were, is, have, these, be, those, other, unamended,
# Nearest to of: in, tbs, for, from, absinthe, nndb, including, lfar,
# Nearest to there: they, it, he, still, said, who, which, now,
# Average loss at step 32000: 3.499419
# Average loss at step 34000: 3.496280
# Average loss at step 36000: 3.459713
# Average loss at step 38000: 3.299885
# Average loss at step 40000: 3.426182
# Nearest to than: or, encryption, cabral, piper, fasci, telco, particular, odp,
# Nearest to s: taunus, ecclesiastical, magnate, had, coma, his, toei, montr,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to its: their, his, the, her, somatic, power, nonaligned, lads,
# Nearest to united: reducing, laserdisc, atlantic, beatrice, upstairs, gia, navy, drumlins,
# Nearest to with: between, when, by, lar, jehu, in, for, using,
# Nearest to who: he, often, which, she, arameans, they, steadfast, realpolitik,
# Nearest to which: that, this, also, who, there, it, often, what,
# Nearest to on: upon, in, at, during, against, jogaila, theogony, about,
# Nearest to it: he, there, this, she, they, which, always, inverting,
# Nearest to would: will, could, can, may, might, should, must, did,
# Nearest to were: are, have, was, had, been, galliard, aki, those,
# Nearest to when: if, before, where, because, while, after, with, then,
# Nearest to are: were, have, is, but, be, include, unamended, although,
# Nearest to of: in, nndb, coughlin, partial, for, from, internationalist, fr,
# Nearest to there: it, they, he, still, now, which, usually, often,
# Average loss at step 42000: 3.435144
# Average loss at step 44000: 3.455919
# Average loss at step 46000: 3.452712
# Average loss at step 48000: 3.351601
# Average loss at step 50000: 3.382718
# Nearest to than: or, encryption, fasci, cabral, much, jiu, cyclase, telco,
# Nearest to s: vinland, his, disestablished, lix, their, whose, and, its,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to its: their, his, the, her, your, power, nonaligned, rosalyn,
# Nearest to united: reducing, laserdisc, upstairs, beatrice, beginning, oedipus, drumlins, gia,
# Nearest to with: between, gymnast, into, using, by, cystitis, lar, upheaval,
# Nearest to who: he, which, they, arameans, often, she, realpolitik, now,
# Nearest to which: this, that, who, what, often, also, where, these,
# Nearest to on: upon, in, through, at, against, about, huge, theogony,
# Nearest to it: he, there, she, this, they, often, now, still,
# Nearest to would: will, could, can, may, might, should, must, did,
# Nearest to were: are, have, was, be, had, those, been, aki,
# Nearest to when: if, while, before, where, after, because, during, but,
# Nearest to are: were, is, have, these, those, be, earthen, aeroplanes,
# Nearest to of: in, including, tbs, and, nevsky, arnauld, lfar, gamers,
# Nearest to there: they, it, he, now, still, she, said, usually,
# Average loss at step 52000: 3.438720
# Average loss at step 54000: 3.427410
# Average loss at step 56000: 3.434471
# Average loss at step 58000: 3.400189
# Average loss at step 60000: 3.395584
# Nearest to than: and, or, encryption, but, much, fasci, mycology, cyclase,
# Nearest to s: ecclesiastical, toei, anglia, prostitution, tiki, canyon, chartres, cumin,
# Nearest to nine: eight, six, seven, five, four, zero, three, one,
# Nearest to its: their, his, the, her, your, power, somatic, nonaligned,
# Nearest to united: laserdisc, reducing, baltic, atlantic, upstairs, gia, navy, beginning,
# Nearest to with: between, by, into, when, gymnast, kusanagi, in, deepwater,
# Nearest to who: he, realpolitik, still, which, arameans, now, often, they,
# Nearest to which: that, this, what, it, who, these, but, there,
# Nearest to on: upon, in, through, about, theogony, educating, noc, athelstan,
# Nearest to it: he, there, she, this, which, now, they, that,
# Nearest to would: could, will, can, may, might, should, must, did,
# Nearest to were: are, had, have, was, those, been, while, be,
# Nearest to when: if, before, although, because, while, after, during, where,
# Nearest to are: were, is, have, those, these, include, be, aeroplanes,
# Nearest to of: in, for, partial, lfar, or, tbs, containing, dissociative,
# Nearest to there: they, it, we, now, still, he, she, this,
# Average loss at step 62000: 3.240150
# Average loss at step 64000: 3.256884
# Average loss at step 66000: 3.408284
# Average loss at step 68000: 3.393202
# Average loss at step 70000: 3.359427
# Nearest to than: or, encryption, gras, lucas, but, fasci, much, cyclase,
# Nearest to s: whose, yourselves, my, baron, toei, gropius, cyril, enlisting,
# Nearest to nine: eight, seven, six, five, four, zero, three, one,
# Nearest to its: their, his, her, the, your, somatic, whose, evangelistic,
# Nearest to united: laserdisc, reducing, navy, border, upstairs, gia, baltic, improvisational,
# Nearest to with: between, by, deepwater, in, lar, surrey, gymnast, helsing,
# Nearest to who: he, realpolitik, she, often, still, they, arameans, now,
# Nearest to which: that, this, what, but, also, however, decompression, often,
# Nearest to on: upon, through, in, about, within, athelstan, huge, cdma,
# Nearest to it: he, there, she, they, this, still, now, inverting,
# Nearest to would: will, could, may, can, might, should, must, cannot,
# Nearest to were: are, have, was, had, be, been, those, galliard,
# Nearest to when: if, because, before, while, however, although, where, was,
# Nearest to are: were, have, is, although, these, include, including, those,
# Nearest to of: including, popeye, in, esperanto, and, gothenburg, fayyum, physical,
# Nearest to there: they, it, we, still, now, he, generally, she,
# Average loss at step 72000: 3.373189
# Average loss at step 74000: 3.349591
# Average loss at step 76000: 3.321210
# Average loss at step 78000: 3.352112
# Average loss at step 80000: 3.375965
# Nearest to than: mycology, much, while, or, but, gras, amperes, lucas,
# Nearest to s: tiki, isbn, medusa, cripple, baron, whose, canyon, disestablished,
# Nearest to nine: eight, seven, five, six, four, three, zero, two,
# Nearest to its: their, his, her, your, the, nonaligned, power, somatic,
# Nearest to united: reducing, laserdisc, navy, air, border, suspects, upstairs, vindhya,
# Nearest to with: between, helsing, when, in, lar, humus, by, gymnast,
# Nearest to who: he, she, realpolitik, they, actually, often, arameans, still,
# Nearest to which: this, that, what, also, typically, usually, but, hypothesize,
# Nearest to on: upon, in, through, under, against, tigray, during, from,
# Nearest to it: he, she, there, this, they, still, inverting, not,
# Nearest to would: will, could, may, can, might, should, must, cannot,
# Nearest to were: are, had, have, was, those, although, been, include,
# Nearest to when: if, before, after, because, during, although, then, while,
# Nearest to are: were, have, include, is, those, these, although, including,
# Nearest to of: nevsky, tbs, including, gothenburg, in, arnauld, lfar, dissociative,
# Nearest to there: they, it, he, we, said, still, now, currently,
# Average loss at step 82000: 3.409543
# Average loss at step 84000: 3.412897
# Average loss at step 86000: 3.390902
# Average loss at step 88000: 3.356072
# Average loss at step 90000: 3.368600
# Nearest to than: or, much, smuggling, but, encryption, mycology, margin, far,
# Nearest to s: whose, isbn, tiki, his, cripple, neanderthals, anglia, taunus,
# Nearest to nine: seven, eight, six, five, four, zero, three, two,
# Nearest to its: their, his, her, your, the, whose, iigs, our,
# Nearest to united: navy, laserdisc, reducing, border, confederate, upstairs, peasantry, gia,
# Nearest to with: between, gymnast, lar, malfunction, by, in, when, cystitis,
# Nearest to who: he, often, which, realpolitik, she, they, arameans, actually,
# Nearest to which: that, this, what, also, who, usually, typically, but,
# Nearest to on: upon, under, onto, through, at, around, messianic, in,
# Nearest to it: he, she, there, this, they, still, never, itself,
# Nearest to would: could, will, might, may, can, should, must, did,
# Nearest to were: are, had, was, have, while, although, those, aki,
# Nearest to when: if, before, after, while, because, although, during, where,
# Nearest to are: were, is, include, have, these, those, although, can,
# Nearest to of: including, for, lfar, during, popeye, arnauld, in, tbs,
# Nearest to there: they, it, he, still, we, said, she, now,
# Average loss at step 92000: 3.399949
# Average loss at step 94000: 3.258964
# Average loss at step 96000: 3.360724
# Average loss at step 98000: 3.244315
# Average loss at step 100000: 3.359236
# Nearest to than: or, much, but, smuggling, and, margin, mycology, fasci,
# Nearest to s: his, my, whose, disestablished, toei, isbn, cruz, the,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to its: their, the, his, somatic, your, her, power, impotence,
# Nearest to united: navy, laserdisc, border, reducing, confederate, peasantry, baltic, neighboring,
# Nearest to with: between, including, in, when, lar, by, into, gymnast,
# Nearest to who: he, she, actually, tanned, which, often, never, still,
# Nearest to which: that, this, what, typically, usually, but, these, who,
# Nearest to on: upon, through, under, at, in, within, against, jogaila,
# Nearest to it: he, she, this, there, they, never, perfective, itself,
# Nearest to would: could, will, might, may, can, should, must, did,
# Nearest to were: are, was, have, those, had, although, include, including,
# Nearest to when: if, before, while, because, although, where, after, though,
# Nearest to are: were, have, those, include, is, these, including, although,
# Nearest to of: including, original, in, and, diversions, gothenburg, nevsky, from,
# Nearest to there: they, still, it, now, we, he, generally, often,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128
bag_window = 2 # Quantas palavras considerar a direita e a esquerda

valid_size = 16
valid_window = 100
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64

graph = tf.Graph()
with graph.as_default():
    # input
    train_dataset = tf.placeholder(tf.int32, shape = [batch_size, bag_window*2])
    train_labels  = tf.placeholder(tf.int32, shape = [batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], 
                                                      stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model
    embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, 
                                                     labels=train_labels, 
                                                     inputs=tf.reduce_sum(embeds, 1), 
                                                     num_sampled=num_sampled, num_classes=vocabulary_size))
    # optmizer
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.818234
# Nearest to up: gupta, chaplain, alliances, serie, lighters, apec, epoxy, sane,
# Nearest to to: stiffer, tarski, izzard, critique, keane, identically, reporting, mitre,
# Nearest to for: churchyard, mis, prototypes, slang, blanks, aside, drank, lad,
# Nearest to would: regained, offending, victoriae, multitasking, testifies, alembert, vrml, aberfoyle,
# Nearest to not: dft, hitters, gadolinium, untranslated, parnassus, thermodynamically, regimes, dominoes,
# Nearest to can: kidnapped, satirize, colonize, hari, nell, collided, periods, burkina,
# Nearest to this: erecting, certifications, mods, advent, ddrmax, mitrokhin, computed, kidnapping,
# Nearest to over: travellers, udo, deceased, missourians, promised, smart, somalia, holdings,
# Nearest to was: entrepreneurship, baz, concrete, unscathed, subsidiaries, michelob, legislative, lea,
# Nearest to been: unionist, sunken, anacharsis, sentiments, dramatists, principe, chartres, unwittingly,
# Nearest to history: antisemitism, jewishencyclopedia, andres, reload, fp, soften, isoleucine, choose,
# Nearest to five: tombaugh, dreyfus, branwell, grew, filtration, subjecting, kemp, duals,
# Nearest to his: enclosures, correcting, vapour, hamill, protectionist, astronomical, towel, assessment,
# Nearest to may: exempted, wedlock, courtship, tradeoff, fluorides, allowance, conduction, charlestown,
# Nearest to that: hollingworth, inflicting, fishery, faisal, artur, burghley, mathura, oses,
# Nearest to have: proclus, fuego, bystander, accumulations, either, beauchamp, lying, appears,
# Average loss at step 2000: 4.599454
# Average loss at step 4000: 3.924970
# Average loss at step 6000: 3.716491
# Average loss at step 8000: 3.527537
# Average loss at step 10000: 3.478065
# Nearest to up: chaplain, lighters, off, women, gupta, poitou, doorman, cuc,
# Nearest to to: may, can, will, reporting, would, exterminating, could, must,
# Nearest to for: jena, butterflies, of, hunyadi, abstaining, tikal, brisance, poetic,
# Nearest to would: could, may, will, can, should, did, must, might,
# Nearest to not: numbered, secede, phocas, glaser, better, vend, slowest, lapland,
# Nearest to can: may, could, would, will, should, must, cannot, to,
# Nearest to this: the, it, any, mentality, canvas, interpretive, a, another,
# Nearest to over: ionized, demotic, when, backers, invoked, tricity, smart, israelite,
# Nearest to was: is, were, had, became, has, are, gprs, starfish,
# Nearest to been: become, avestan, arundel, omphalos, boulton, depths, orcus, receding,
# Nearest to history: list, ecclesiology, regiment, life, spontaneity, patron, rams, antisemitism,
# Nearest to five: seven, four, three, eight, zero, six, nine, two,
# Nearest to his: her, their, its, the, peroxide, blotting, convenes, disquieting,
# Nearest to may: can, would, could, will, must, should, to, kabila,
# Nearest to that: which, who, try, aaliyah, excepting, involving, when, obiang,
# Nearest to have: has, had, capping, ferraris, having, entrepot, mentor, bystander,
# Average loss at step 12000: 3.490014
# Average loss at step 14000: 3.437164
# Average loss at step 16000: 3.429780
# Average loss at step 18000: 3.398281
# Average loss at step 20000: 3.217720
# Nearest to up: off, them, him, jasmuheen, counsel, jewel, tocharians, lighters,
# Nearest to to: will, would, may, must, could, might, can, keypad,
# Nearest to for: underlying, after, butterflies, lle, jena, libation, maid, zamora,
# Nearest to would: will, could, may, should, can, must, might, did,
# Nearest to not: now, hanyu, secede, so, still, what, hyped, often,
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to this: which, that, it, canvas, kashrut, the, another, actresses,
# Nearest to over: during, throughout, under, before, demotic, at, ionized, aeroflot,
# Nearest to was: is, were, became, had, has, polyandry, being, machado,
# Nearest to been: become, burgoyne, avestan, flint, afrique, come, snacks, cloaca,
# Nearest to history: list, patron, vetoes, beards, ecclesiology, chopper, gallardo, gentlemen,
# Nearest to five: seven, six, four, zero, eight, three, nine, two,
# Nearest to his: her, their, its, the, s, my, louth, whose,
# Nearest to may: can, would, must, will, could, should, might, cannot,
# Nearest to that: which, this, however, where, who, what, aaliyah, when,
# Nearest to have: has, had, having, were, pantera, be, are, capping,
# Average loss at step 22000: 3.355322
# Average loss at step 24000: 3.281162
# Average loss at step 26000: 3.249202
# Average loss at step 28000: 3.285152
# Average loss at step 30000: 3.227068
# Nearest to up: off, down, out, chaplain, them, him, counsel, ncaa,
# Nearest to to: would, will, must, might, may, could, shall, should,
# Nearest to for: cascade, violinist, of, confucianism, after, gave, against, renoir,
# Nearest to would: will, could, may, can, must, should, might, did,
# Nearest to not: still, hyped, practicality, never, now, converse, phocas, gabbro,
# Nearest to can: could, may, will, must, would, should, cannot, might,
# Nearest to this: which, it, what, canvas, another, the, that, musicals,
# Nearest to over: herc, gd, demotic, throughout, within, before, catalogues, during,
# Nearest to was: is, became, were, had, being, are, has, makes,
# Nearest to been: become, come, be, begun, avestan, afrique, tanner, boulton,
# Nearest to history: list, philosophy, mcintyre, facade, multiples, prophesied, usage, noaa,
# Nearest to five: four, six, three, seven, eight, nine, zero, two,
# Nearest to his: her, their, its, my, the, s, chukotka, jubilees,
# Nearest to may: can, must, would, should, could, will, might, cannot,
# Nearest to that: which, although, where, however, this, what, pheromones, barrelled,
# Nearest to have: has, had, having, thunderbirds, include, produce, are, were,
# Average loss at step 32000: 3.017910
# Average loss at step 34000: 3.206312
# Average loss at step 36000: 3.190421
# Average loss at step 38000: 3.168614
# Average loss at step 40000: 3.158997
# Nearest to up: off, out, counsel, curious, pollination, litchfield, down, rectangular,
# Nearest to to: would, will, could, growths, should, must, cannot, may,
# Nearest to for: against, of, crooks, minorca, bruckner, cam, without, libation,
# Nearest to would: will, should, could, may, must, can, might, did,
# Nearest to not: still, now, never, transplant, plumes, amalric, sometimes, hyped,
# Nearest to can: could, will, must, cannot, may, would, should, might,
# Nearest to this: it, the, another, which, a, that, any, every,
# Nearest to over: demotic, kagoshima, gd, throughout, within, under, aerobatic, at,
# Nearest to was: is, were, became, are, has, being, makes, had,
# Nearest to been: become, begun, be, snacks, being, come, was, occurred,
# Nearest to history: eudoxia, naia, arbitrate, classification, gardener, feyerabend, romantics, bookmarks,
# Nearest to five: six, eight, seven, four, zero, nine, three, two,
# Nearest to his: her, their, its, my, your, our, the, convenes,
# Nearest to may: must, will, could, can, would, should, might, cannot,
# Nearest to that: which, however, although, this, barrelled, herndon, fillmore, why,
# Nearest to have: has, had, having, be, refer, contain, inundated, include,
# Average loss at step 42000: 3.214865
# Average loss at step 44000: 3.136623
# Average loss at step 46000: 3.147675
# Average loss at step 48000: 3.062948
# Average loss at step 50000: 3.065975
# Nearest to up: off, out, counsel, together, them, keyboardist, him, down,
# Nearest to to: will, could, must, should, can, may, might, shall,
# Nearest to for: when, of, without, while, tart, pus, cam, against,
# Nearest to would: could, will, may, should, might, must, can, did,
# Nearest to not: never, still, transplant, now, secede, functionals, gabbro, preaching,
# Nearest to can: could, may, must, should, might, cannot, will, would,
# Nearest to this: which, it, another, what, realplayer, probably, interconnected, kashrut,
# Nearest to over: around, within, under, gd, during, throughout, hopeless, kagoshima,
# Nearest to was: is, were, became, are, had, being, becomes, makes,
# Nearest to been: become, begun, appeared, was, already, survived, omphalos, remained,
# Nearest to history: modern, bookmarks, beige, mcintyre, portal, reconstructions, romantics, list,
# Nearest to five: six, four, seven, three, eight, two, nine, zero,
# Nearest to his: her, their, its, my, the, your, our, s,
# Nearest to may: can, should, must, would, could, might, will, cannot,
# Nearest to that: which, aaliyah, although, sprengel, where, dumpster, fairfield, eubulides,
# Nearest to have: has, had, having, contain, produce, refer, thunderbirds, ve,
# Average loss at step 52000: 3.093646
# Average loss at step 54000: 3.090162
# Average loss at step 56000: 2.920278
# Average loss at step 58000: 3.019518
# Average loss at step 60000: 3.042094
# Nearest to up: off, down, together, out, counsel, pollination, sfor, him,
# Nearest to to: must, could, might, would, will, shall, may, should,
# Nearest to for: before, remarry, after, cascade, sangha, renoir, violinist, lifts,
# Nearest to would: will, could, might, may, should, must, did, can,
# Nearest to not: never, now, nothing, hyped, secede, hanyu, oven, multiplexing,
# Nearest to can: may, could, should, might, will, cannot, must, would,
# Nearest to this: it, another, every, which, the, each, extraterrestrials, any,
# Nearest to over: during, before, demotic, within, across, throughout, around, under,
# Nearest to was: is, became, were, remains, are, had, becomes, has,
# Nearest to been: become, begun, remained, survived, come, be, repeatedly, tico,
# Nearest to history: list, usage, form, amuse, philosophy, journal, evolution, development,
# Nearest to five: six, eight, seven, four, three, nine, zero, two,
# Nearest to his: her, their, its, my, s, our, your, the,
# Nearest to may: can, could, might, should, must, would, will, cannot,
# Nearest to that: which, however, what, how, encompassing, when, although, where,
# Nearest to have: has, had, having, contain, include, produce, refer, allow,
# Average loss at step 62000: 3.005442
# Average loss at step 64000: 2.919137
# Average loss at step 66000: 2.924734
# Average loss at step 68000: 2.978356
# Average loss at step 70000: 3.009372
# Nearest to up: off, together, counsel, down, pollination, herodotus, sfor, lighters,
# Nearest to to: will, must, could, might, cannot, can, would, should,
# Nearest to for: after, without, of, libation, minorca, graced, cam, by,
# Nearest to would: will, might, could, may, should, must, can, cannot,
# Nearest to not: never, still, nothing, hyped, phocas, now, rarely, munch,
# Nearest to can: could, cannot, may, must, will, should, might, would,
# Nearest to this: another, which, it, vocally, what, rameau, that, kolkata,
# Nearest to over: under, about, within, throughout, fevers, gd, ago, off,
# Nearest to was: is, were, became, has, are, remains, becomes, makes,
# Nearest to been: become, begun, be, remained, existed, was, fallen, grown,
# Nearest to history: evolution, journal, terms, reconstructions, philosophy, origins, usage, anagrams,
# Nearest to five: seven, six, three, four, two, zero, eight, transonic,
# Nearest to his: their, her, its, your, my, s, our, the,
# Nearest to may: should, must, can, might, could, would, will, cannot,
# Nearest to that: which, wearing, gangrene, jumpers, where, raum, this, boreal,
# Nearest to have: had, has, having, contain, include, allow, refer, find,
# Average loss at step 72000: 2.942899
# Average loss at step 74000: 2.873517
# Average loss at step 76000: 2.992157
# Average loss at step 78000: 3.005998
# Average loss at step 80000: 2.849528
# Nearest to up: off, down, back, counsel, together, sfor, lighters, out,
# Nearest to to: will, might, must, can, shall, should, would, could,
# Nearest to for: without, minorca, after, remarry, juggling, concourse, stimson, cam,
# Nearest to would: could, will, might, must, should, can, may, cannot,
# Nearest to not: never, now, still, nothing, hyped, so, also, actually,
# Nearest to can: could, must, may, should, will, might, cannot, would,
# Nearest to this: it, which, another, what, the, sometimes, a, vocally,
# Nearest to over: throughout, gd, during, demotic, ago, across, about, werewolves,
# Nearest to was: is, were, became, becomes, are, had, makes, has,
# Nearest to been: become, occurred, begun, appeared, grown, survived, increased, existed,
# Nearest to history: list, concept, philosophy, introduction, warwickshire, multiples, plaintiffs, biography,
# Nearest to five: seven, six, eight, four, three, zero, nine, two,
# Nearest to his: her, their, its, your, my, our, the, s,
# Nearest to may: can, might, must, should, could, will, would, cannot,
# Nearest to that: which, fillmore, sprengel, tighten, retroviral, merritt, who, this,
# Nearest to have: has, had, having, contain, provide, offer, ve, be,
# Average loss at step 82000: 2.938850
# Average loss at step 84000: 2.891418
# Average loss at step 86000: 2.920597
# Average loss at step 88000: 2.940243
# Average loss at step 90000: 2.830653
# Nearest to up: off, down, counsel, back, sfor, out, toughness, together,
# Nearest to to: will, must, might, cannot, should, would, can, may,
# Nearest to for: yzerman, minorca, after, including, noc, libation, linseed, juggling,
# Nearest to would: will, might, could, should, must, may, can, cannot,
# Nearest to not: still, never, nothing, hyped, gam, almost, secede, financially,
# Nearest to can: must, may, should, could, will, might, cannot, would,
# Nearest to this: it, another, which, what, the, any, realplayer, that,
# Nearest to over: throughout, across, around, about, ago, denominational, werewolves, during,
# Nearest to was: is, were, became, had, has, becomes, remains, are,
# Nearest to been: become, existed, evolved, occurred, begun, be, fallen, grown,
# Nearest to history: delft, journal, development, list, course, custer, raskin, introduction,
# Nearest to five: four, six, seven, three, eight, zero, nine, two,
# Nearest to his: their, her, its, my, your, our, whose, the,
# Nearest to may: must, should, might, can, will, could, would, cannot,
# Nearest to that: which, where, who, tighten, fillmore, when, fairfield, merritt,
# Nearest to have: has, had, contain, having, require, ve, produce, represent,
# Average loss at step 92000: 2.898439
# Average loss at step 94000: 2.887000
# Average loss at step 96000: 2.713411
# Average loss at step 98000: 2.457292
# Average loss at step 100000: 2.708875
# Nearest to up: off, counsel, out, down, together, ready, sfor, into,
# Nearest to to: must, would, will, could, should, towards, cannot, growths,
# Nearest to for: after, without, including, despite, surreptitiously, shook, zamora, libation,
# Nearest to would: could, might, will, should, must, can, may, did,
# Nearest to not: never, still, nothing, indeed, hyped, phocas, almost, rarely,
# Nearest to can: must, should, could, might, will, cannot, may, would,
# Nearest to this: another, which, some, it, every, the, celebrated, what,
# Nearest to over: throughout, across, gd, around, about, aeroflot, during, off,
# Nearest to was: is, became, remains, makes, remained, were, gets, does,
# Nearest to been: become, existed, fallen, evolved, occurred, come, already, begun,
# Nearest to history: journal, origins, development, exploitation, usage, life, list, philosophy,
# Nearest to five: seven, four, six, three, eight, zero, nine, two,
# Nearest to his: their, her, its, your, my, s, the, whose,
# Nearest to may: might, should, must, can, could, would, will, cannot,
# Nearest to that: which, where, however, although, fillmore, who, aaliyah, tighten,
# Nearest to have: had, has, contain, having, produce, ve, require, give,

# %%
words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
